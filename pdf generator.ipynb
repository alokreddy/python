# %%
from os import chdir, getcwd, listdir, path
from time import strftime
from win32com import client

def count_files(filetype):
    ''' (str) -> int
    Returns the number of files given a specified file type.
    >>> count_files(".docx")
    11
    '''
    count_files = 0
    for files in listdir(folder):
        if files.endswith(filetype):
            count_files += 1
    return count_files

# Function "check_path" is used to check whether the path the user provided does
# actually exist. The user is prompted for a path until the existence of the
# provided path has been verified.

def check_path(prompt):
    ''' (str) -> str
    Verifies if the provided absolute path does exist.
    '''
    abs_path = raw_input(prompt)
    while path.exists(abs_path) != True:
        print "\nThe specified path does not exist.\n"
        abs_path = raw_input(prompt)
    return abs_path    
    
print "\n"

folder = check_path("Provide absolute path for the folder: ")

# Change the directory.

chdir(folder)

# Count the number of docx and doc files in the specified folder.

num_docx = count_files(".docx")
num_doc = count_files(".doc")

# Check if the number of docx or doc files is equal to 0 (= there are no files
# to convert) and if so stop executing the script. 

if num_docx + num_doc == 0:
    print "\nThe specified folder does not contain docx or docs files.\n"
    print strftime("%H:%M:%S"), "There are no files to convert. BYE, BYE!."
    exit()
else:
    print "\nNumber of doc and docx files: ", num_docx + num_doc, "\n"
    print strftime("%H:%M:%S"), "Starting to convert files ...\n"

# Try to open win32com instance. If unsuccessful return an error message.

try:
    word = client.DispatchEx("Word.Application")
    for files in listdir(getcwd()):
        if files.endswith(".docx"):
            new_name = files.replace(".docx", r".pdf")
            in_file = path.abspath(folder + "\\" + files)
            new_file = path.abspath(folder + "\\" + new_name)
            doc = word.Documents.Open(in_file)
            print strftime("%H:%M:%S"), " docx -> pdf ", path.relpath(new_file)
            doc.SaveAs(new_file, FileFormat = 17)
            doc.Close()
        if files.endswith(".doc"):
            new_name = files.replace(".doc", r".pdf")
            in_file = path.abspath(folder + "\\" + files)
            new_file = path.abspath(folder + "\\" + new_name)
            doc = word.Documents.Open(in_file)
            print strftime("%H:%M:%S"), " doc  -> pdf ", path.relpath(new_file)
            doc.SaveAs(new_file, FileFormat = 17)
            doc.Close()
except Exception, e:
    print e
finally:
    word.Quit()

print "\n", strftime("%H:%M:%S"), "Finished converting files."    

# Count the number of pdf files.

num_pdf = count_files(".pdf")   

print "\nNumber of pdf files: ", num_pdf

# Check if the number of docx and doc file is equal to the number of files.

if num_docx + num_doc == num_pdf:
    print "\nNumber of doc and docx files is equal to number of pdf files."
else:
    print "\nNumber of doc and docx files is not equal to number of pdf files."
# Out:
# Provide absolute path for the folder: C:\Users\ReddyAl\Documents\CRA\FY17 Q2\Summary Statements\word
#
# Number of doc and docx files:  117
#
# 12:04:19 Starting to convert files ...
#
# 12:04:20  docx -> pdf  CRA Incentive Plan FY17 Q2 Abecassis, Revital.pdf
# 12:04:23  docx -> pdf  CRA Incentive Plan FY17 Q2 Akinola, Abiodun.pdf
# 12:04:24  docx -> pdf  CRA Incentive Plan FY17 Q2 Allerhand, Dorothy.pdf
# 12:04:24  docx -> pdf  CRA Incentive Plan FY17 Q2 Alves Domingues, Carla.pdf
# 12:04:25  docx -> pdf  CRA Incentive Plan FY17 Q2 Andre, Julie.pdf
# 12:04:25  docx -> pdf  CRA Incentive Plan FY17 Q2 Ascari, Isabella.pdf
# 12:04:26  docx -> pdf  CRA Incentive Plan FY17 Q2 Azarian, Inna.pdf
# 12:04:26  docx -> pdf  CRA Incentive Plan FY17 Q2 Badenhorst, Ruan.pdf
# 12:04:27  docx -> pdf  CRA Incentive Plan FY17 Q2 Ballhausen, Thomas.pdf
# 12:04:27  docx -> pdf  CRA Incentive Plan FY17 Q2 Balukiewicz, Anna.pdf
# 12:04:28  docx -> pdf  CRA Incentive Plan FY17 Q2 Baniqued, Al Ryan.pdf
# 12:04:28  docx -> pdf  CRA Incentive Plan FY17 Q2 Barreda Ramirez, Pilar.pdf
# 12:04:28  docx -> pdf  CRA Incentive Plan FY17 Q2 Beaver, Angela.pdf
# 12:04:29  docx -> pdf  CRA Incentive Plan FY17 Q2 Bechtold, Holger.pdf
# 12:04:29  docx -> pdf  CRA Incentive Plan FY17 Q2 Biliavskyi, Andrii.pdf
# 12:04:29  docx -> pdf  CRA Incentive Plan FY17 Q2 Blazencic-Mladenovic, Vera.pdf
# 12:04:30  docx -> pdf  CRA Incentive Plan FY17 Q2 Boden, Andrew.pdf
# 12:04:30  docx -> pdf  CRA Incentive Plan FY17 Q2 Bonin, Gersende.pdf
# 12:04:30  docx -> pdf  CRA Incentive Plan FY17 Q2 Bora, Dipenjit.pdf
# 12:04:31  docx -> pdf  CRA Incentive Plan FY17 Q2 Burghardt, Janet.pdf
# 12:04:31  docx -> pdf  CRA Incentive Plan FY17 Q2 Busche, Karin.pdf
# 12:04:31  docx -> pdf  CRA Incentive Plan FY17 Q2 Caceres, Gabriela.pdf
# 12:04:32  docx -> pdf  CRA Incentive Plan FY17 Q2 Calaveras Ramos, Alicia.pdf
# 12:04:32  docx -> pdf  CRA Incentive Plan FY17 Q2 Cambricoli, Luciana.pdf
# 12:04:32  docx -> pdf  CRA Incentive Plan FY17 Q2 Chandra, Thayalavishnu.pdf
# 12:04:33  docx -> pdf  CRA Incentive Plan FY17 Q2 Chang, Hsueh-Fang.pdf
# 12:04:33  docx -> pdf  CRA Incentive Plan FY17 Q2 Davrath, Linda.pdf
# 12:04:33  docx -> pdf  CRA Incentive Plan FY17 Q2 Dayag, Ariane Marie.pdf
# 12:04:34  docx -> pdf  CRA Incentive Plan FY17 Q2 De Frutos Reina, Veronica.pdf
# 12:04:34  docx -> pdf  CRA Incentive Plan FY17 Q2 De Giglio, Andrea.pdf
# 12:04:34  docx -> pdf  CRA Incentive Plan FY17 Q2 Demin, Dmitry.pdf
# 12:04:35  docx -> pdf  CRA Incentive Plan FY17 Q2 Deng, HuiJun.pdf
# 12:04:35  docx -> pdf  CRA Incentive Plan FY17 Q2 Dolinova, Olga.pdf
# 12:04:35  docx -> pdf  CRA Incentive Plan FY17 Q2 Dykun, Yaroslav.pdf
# 12:04:36  docx -> pdf  CRA Incentive Plan FY17 Q2 e Silva, Wagner.pdf
# 12:04:36  docx -> pdf  CRA Incentive Plan FY17 Q2 Engraff, Javier.pdf
# 12:04:36  docx -> pdf  CRA Incentive Plan FY17 Q2 Episcopo, Andrea.pdf
# 12:04:36  docx -> pdf  CRA Incentive Plan FY17 Q2 Espinoza Munoz, Claudia.pdf
# 12:04:37  docx -> pdf  CRA Incentive Plan FY17 Q2 Fan, Chenjiao.pdf
# 12:04:37  docx -> pdf  CRA Incentive Plan FY17 Q2 Franke, Renata.pdf
# 12:04:37  docx -> pdf  CRA Incentive Plan FY17 Q2 Galinier, Elisabeth.pdf
# 12:04:38  docx -> pdf  CRA Incentive Plan FY17 Q2 Gan, Chun.pdf
# 12:04:38  docx -> pdf  CRA Incentive Plan FY17 Q2 Gan, Quan.pdf
# 12:04:38  docx -> pdf  CRA Incentive Plan FY17 Q2 Ghedini, Laura.pdf
# 12:04:39  docx -> pdf  CRA Incentive Plan FY17 Q2 Hibbitts, Pamela.pdf
# 12:04:39  docx -> pdf  CRA Incentive Plan FY17 Q2 Hines, Naja.pdf
# 12:04:39  docx -> pdf  CRA Incentive Plan FY17 Q2 Hritz, Viktoria.pdf
# 12:04:40  docx -> pdf  CRA Incentive Plan FY17 Q2 Huang, Ting.pdf
# 12:04:40  docx -> pdf  CRA Incentive Plan FY17 Q2 Ionita, Valentina.pdf
# 12:04:40  docx -> pdf  CRA Incentive Plan FY17 Q2 Irvine, Jason.pdf
# 12:04:41  docx -> pdf  CRA Incentive Plan FY17 Q2 JanseVanVuuren, CJ.pdf
# 12:04:41  docx -> pdf  CRA Incentive Plan FY17 Q2 Jeffrey, Glenn.pdf
# 12:04:41  docx -> pdf  CRA Incentive Plan FY17 Q2 Jensen, Leanne.pdf
# 12:04:42  docx -> pdf  CRA Incentive Plan FY17 Q2 Jestila, Katherine.pdf
# 12:04:42  docx -> pdf  CRA Incentive Plan FY17 Q2 Ji, Minlan.pdf
# 12:04:42  docx -> pdf  CRA Incentive Plan FY17 Q2 Jung, Jaiheon.pdf
# 12:04:42  docx -> pdf  CRA Incentive Plan FY17 Q2 Karim, Mahareen.pdf
# 12:04:43  docx -> pdf  CRA Incentive Plan FY17 Q2 Kelley, Thomas.pdf
# 12:04:43  docx -> pdf  CRA Incentive Plan FY17 Q2 Keune, Susanne.pdf
# 12:04:43  docx -> pdf  CRA Incentive Plan FY17 Q2 Kim, Jiyoung.pdf
# 12:04:44  docx -> pdf  CRA Incentive Plan FY17 Q2 Kim, YouGyung.pdf
# 12:04:44  docx -> pdf  CRA Incentive Plan FY17 Q2 Koesling, Stefan.pdf
# 12:04:44  docx -> pdf  CRA Incentive Plan FY17 Q2 Kovelenova, Marina.pdf
# 12:04:45  docx -> pdf  CRA Incentive Plan FY17 Q2 Kruszynska, Anna.pdf
# 12:04:45  docx -> pdf  CRA Incentive Plan FY17 Q2 Lane-Blake, Elizabeth.pdf
# 12:04:45  docx -> pdf  CRA Incentive Plan FY17 Q2 Lang-Lenton Guerra, Ana Teresa.pdf
# 12:04:46  docx -> pdf  CRA Incentive Plan FY17 Q2 Locher, J.pdf
# 12:04:46  docx -> pdf  CRA Incentive Plan FY17 Q2 Mahler, Manuela.pdf
# 12:04:46  docx -> pdf  CRA Incentive Plan FY17 Q2 Mazaev, Pavel.pdf
# 12:04:47  docx -> pdf  CRA Incentive Plan FY17 Q2 Methanukroh, Tharinee.pdf
# 12:04:47  docx -> pdf  CRA Incentive Plan FY17 Q2 Mishra, Rachna.pdf
# 12:04:47  docx -> pdf  CRA Incentive Plan FY17 Q2 Morales Perez, Virginia.pdf
# 12:04:48  docx -> pdf  CRA Incentive Plan FY17 Q2 Moravcova, Zuzana.pdf
# 12:04:48  docx -> pdf  CRA Incentive Plan FY17 Q2 Motiu, Stefana.pdf
# 12:04:48  docx -> pdf  CRA Incentive Plan FY17 Q2 Naccarato, Colleen.pdf
# 12:04:49  docx -> pdf  CRA Incentive Plan FY17 Q2 Nare, Rudzani.pdf
# 12:04:49  docx -> pdf  CRA Incentive Plan FY17 Q2 Onoprienko, Alexey.pdf
# 12:04:49  docx -> pdf  CRA Incentive Plan FY17 Q2 Otmi, Meital.pdf
# 12:04:49  docx -> pdf  CRA Incentive Plan FY17 Q2 Parigi, Lisa.pdf
# 12:04:50  docx -> pdf  CRA Incentive Plan FY17 Q2 Park, Jackline.pdf
# 12:04:50  docx -> pdf  CRA Incentive Plan FY17 Q2 Park, Sunjung.pdf
# 12:04:50  docx -> pdf  CRA Incentive Plan FY17 Q2 Peter, Anett.pdf
# 12:04:51  docx -> pdf  CRA Incentive Plan FY17 Q2 Pina, Lorenzo.pdf
# 12:04:51  docx -> pdf  CRA Incentive Plan FY17 Q2 Plesea, Liliana.pdf
# 12:04:51  docx -> pdf  CRA Incentive Plan FY17 Q2 Powierza, Anna.pdf
# 12:04:52  docx -> pdf  CRA Incentive Plan FY17 Q2 Rech, Stefania.pdf
# 12:04:52  docx -> pdf  CRA Incentive Plan FY17 Q2 Reese, Lacy.pdf
# 12:04:52  docx -> pdf  CRA Incentive Plan FY17 Q2 Rico, Diana.pdf
# 12:04:53  docx -> pdf  CRA Incentive Plan FY17 Q2 Ristic, Bojan.pdf
# 12:04:53  docx -> pdf  CRA Incentive Plan FY17 Q2 Roche, Carol.pdf
# 12:04:53  docx -> pdf  CRA Incentive Plan FY17 Q2 Romanik, Joanna.pdf
# 12:04:54  docx -> pdf  CRA Incentive Plan FY17 Q2 Sarbu, Catalina.pdf
# 12:04:54  docx -> pdf  CRA Incentive Plan FY17 Q2 Scanes, Karen.pdf
# 12:04:54  docx -> pdf  CRA Incentive Plan FY17 Q2 Shaginyan, Yuri.pdf
# 12:04:54  docx -> pdf  CRA Incentive Plan FY17 Q2 Sheng, Defeng.pdf
# 12:04:55  docx -> pdf  CRA Incentive Plan FY17 Q2 Singleton, Michelle.pdf
# 12:04:55  docx -> pdf  CRA Incentive Plan FY17 Q2 Soto, Claudia.pdf
# 12:04:55  docx -> pdf  CRA Incentive Plan FY17 Q2 Steyn, Natasha.pdf
# 12:04:56  docx -> pdf  CRA Incentive Plan FY17 Q2 Talbot, Charlene.pdf
# 12:04:56  docx -> pdf  CRA Incentive Plan FY17 Q2 Terczynski, Artur.pdf
# 12:04:56  docx -> pdf  CRA Incentive Plan FY17 Q2 Tham, Ee Lean.pdf
# 12:04:57  docx -> pdf  CRA Incentive Plan FY17 Q2 Ticha, Michaela.pdf
# 12:04:57  docx -> pdf  CRA Incentive Plan FY17 Q2 Tolk, Ursel.pdf
# 12:04:57  docx -> pdf  CRA Incentive Plan FY17 Q2 Tychmanowicz, Krzysztof.pdf
# 12:04:58  docx -> pdf  CRA Incentive Plan FY17 Q2 Valentelis, Rimantas.pdf
# 12:04:58  docx -> pdf  CRA Incentive Plan FY17 Q2 Van Den Heuvel, Marco.pdf
# 12:04:58  docx -> pdf  CRA Incentive Plan FY17 Q2 Vandrey, Felicia.pdf
# 12:04:59  docx -> pdf  CRA Incentive Plan FY17 Q2 Vannetta, Hannelore.pdf
# 12:04:59  docx -> pdf  CRA Incentive Plan FY17 Q2 Vastag, Laszlo.pdf
# 12:04:59  docx -> pdf  CRA Incentive Plan FY17 Q2 Vaught, Charles.pdf
# 12:05:00  docx -> pdf  CRA Incentive Plan FY17 Q2 Vazquez-Gundin, Fernando.pdf
# 12:05:00  docx -> pdf  CRA Incentive Plan FY17 Q2 Vladimirova, Vera.pdf
# 12:05:00  docx -> pdf  CRA Incentive Plan FY17 Q2 Xu, Ya.pdf
# 12:05:01  docx -> pdf  CRA Incentive Plan FY17 Q2 Yuan, Qian.pdf
# 12:05:01  docx -> pdf  CRA Incentive Plan FY17 Q2 Zabarko, Larysa.pdf
# 12:05:01  docx -> pdf  CRA Incentive Plan FY17 Q2 Zhang, Shuying.pdf
# 12:05:02  docx -> pdf  CRA Incentive Plan FY17 Q2 Zuric, Mirjana.pdf
#
# 12:05:02 Finished converting files.
#
# Number of pdf files:  117
#
# Number of doc and docx files is equal to number of pdf files.
